# %% [markdown]
# ![alt tag](https://codelearn.io/Upload/Blog/xu-ly-du-lieu-voi-pandas-trong-python-63725977973.8696.jpg)

# %% [markdown]
# # **What is Pandas**
# Thư viện **Pandas** cung cấp các cấu trúc dữ liệu hiệu suất cao, dễ sử dụng và các công cụ phân tích dữ liệu. Cấu trúc dữ liệu chính là DataFrame, có thể coi đây là một bảng 2D trong bộ nhớ (giống như một bảng tính, với tên cột và nhãn). Nhiều tính năng có sẵn trong Excel có sẵn theo chương trình, chẳng hạn như tạo bảng tổng hợp, tính toán cột dựa trên các cột khác, vẽ biểu đồ, v.v. Có thể nhóm các hàng theo giá trị cột hoặc nối các bảng giống như trong SQL. **Pandas** cũng rất giỏi trong việc xử lý chuỗi thời gian. 🐼

# %% [markdown]
# # **Reference**
# https://nbviewer.org/github/ageron/handson-ml2/blob/master/tools_pandas.ipynb

# %% [markdown]
# # **Pandas: Import**

# %% [markdown]
# Import thư viện **pandas**. Hầu hết mọi người sử dụng nó dưới dạng **pd**

# %%
import pandas as pd

# %% [markdown]
# # **Saving & Loading**
# > **Pandas** có thể lưu **DataFrame** vào các phần phụ trợ khác nhau, bao gồm các định dạng tệp như $CSV, Excel, JSON, HTML$ và $HDF5$ hoặc vào cơ sở dữ liệu $SQL$

# %%
achievements = pd.DataFrame([["A+", "A", "A+", "Brilliant"],
                             ["B", "A", "A", "Good"],
                             ["B+", "B", "C", "Average"]],
                             index=["Kiet", "Toan", "Luu"],
                             columns=["Math", "English", "Physics", "achievements"])
achievements
# Out:
#      Math English Physics achievements
# Kiet   A+       A      A+    Brilliant
# Toan    B       A       A         Good
# Luu    B+       B       C      Average

# %% [markdown]
# ### **Saving**
# Lưu với các định dạng $CSV, HTML, JSON$

# %%
achievements.to_csv("achievements.csv")
achievements.to_html("achievements.html")
achievements.to_json("achievements.json")

# %% [markdown]
# File đã được tạo thành công
#
# ![alt tag](https://scontent.fhan14-1.fna.fbcdn.net/v/t1.15752-9/261043944_342540860969886_421972531442407130_n.png?_nc_cat=104&ccb=1-5&_nc_sid=ae9488&_nc_ohc=RlNiZOkh3YQAX_a5Fvh&_nc_ht=scontent.fhan14-1.fna&oh=5d9a7152c28c0f5934b89b09cf470bad&oe=61C50EDF)

# %% [markdown]
# Hãy xem qua những gì đã được lưu

# %%
for filename in ("achievements.csv", "achievements.html", "achievements.json"):
    print(f'------------------ {filename} ---------------')
    with open(filename, "rt") as f:
        print(f.read())
        print()
# Out:
# ------------------ achievements.csv ---------------
# ,Math,English,Physics,achievements
# Kiet,A+,A,A+,Brilliant
# Toan,B,A,A,Good
# Luu,B+,B,C,Average
#
#
# ------------------ achievements.html ---------------
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Math</th>
#       <th>English</th>
#       <th>Physics</th>
#       <th>achievements</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Kiet</th>
#       <td>A+</td>
#       <td>A</td>
#       <td>A+</td>
#       <td>Brilliant</td>
#     </tr>
#     <tr>
#       <th>Toan</th>
#       <td>B</td>
#       <td>A</td>
#       <td>A</td>
#       <td>Good</td>
#     </tr>
#     <tr>
#       <th>Luu</th>
#       <td>B+</td>
#       <td>B</td>
#       <td>C</td>
#       <td>Average</td>
#     </tr>
#   </tbody>
# </table>
#
# ------------------ achievements.json ---------------
# ...

# %% [markdown]
# ### **Loading**

# %% [markdown]
# Tải lại tệp $CSV$ vào một **DataFrame**

# %%
achievements_csv_load = pd.read_csv("achievements.csv", index_col = 0)
achievements_csv_load
# Out:
#      Math English Physics achievements
# Kiet   A+       A      A+    Brilliant
# Toan    B       A       A         Good
# Luu    B+       B       C      Average

# %% [markdown]
# Đọc dữ liệu từ **Github**, ở chế độ **view raw**

# %%
fish_dataset = "https://raw.githubusercontent.com/HiImKing1509/Dataset/main/fish.csv"
fish = pd.read_csv(fish_dataset, index_col=0)
fish
# Out:
#          Weight  Length1  Length2  Length3   Height   Width
# Species
# Bream     242.0     23.2     25.4     30.0  11.5200  4.0200
# Bream     290.0     24.0     26.3     31.2  12.4800  4.3056
# Bream     340.0     23.9     26.5     31.1  12.3778  4.6961
# Bream     363.0     26.3     29.0     33.5  12.7300  4.4555
# Bream     430.0     26.5     29.0     34.0  12.4440  5.1340
# ...         ...      ...      ...      ...      ...     ...
# Smelt      12.2     11.5     12.2     13.4   2.0904  1.3936
# Smelt      13.4     11.7     12.4     13.5   2.4300  1.2690
# Smelt      12.2     12.1     13.0     13.8   2.2770  1.2558
# Smelt      19.7     13.2     14.3     15.2   2.8728  2.0672
# Smelt      19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 6 columns]

# %% [markdown]
# Đọc dữ liệu từ **Github** thông qua việc clone đường dẫn về máy

# %%
# !git clone https://github.com/HiImKing1509/Dataset.git
# Out:
# Cloning into 'Dataset'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 18 (delta 2), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (18/18), done.

# %%
my_dataset = pd.read_csv("/content/Dataset/weather.csv")
my_dataset
# Out:
#       Temperature_c  Humidity  ...  Rain  Description
# 0         -0.555556      0.92  ...     0         Cold
# 1         21.111111      0.73  ...     1         Warm
# 2         16.600000      0.97  ...     1       Normal
# 3          1.600000      0.82  ...     1         Cold
# 4          2.194444      0.60  ...     1         Cold
# ...             ...       ...  ...   ...          ...
# 9995      10.022222      0.95  ...     1       Normal
# 9996       8.633333      0.64  ...     1       Normal
# 9997       5.977778      0.93  ...     1       Normal
# 9998       9.788889      0.78  ...     1       Normal
# 9999      11.138889      0.79  ...     1       Normal
#
# [10000 rows x 8 columns]
